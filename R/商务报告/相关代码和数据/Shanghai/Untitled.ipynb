# %%
import pandas as pd
#读取csv文件数据
df = pd.read_csv('shanghaiWeather.csv',encoding='utf-8')
df.head()
# Out:
#          date  AQI Level  PM2.5  PM10  SO2   CO  NO2  O3_8h
# 0  2014-01-01  195  中度污染    147   181   63  1.7   99     61
# 1  2014-01-02  147  轻度污染    113   131   37  1.6   95     60
# 2  2014-01-03  189  中度污染    142   163   56  1.4   96     45
# 3  2014-01-04  151  中度污染    115   125   36  1.2   64     38
# 4  2014-01-05   65     良     47    60   25  1.0   63     31

# %%
df2 = df['Level'].value_counts()
df2
# Out:
# 良       1018
# 优        360
# 轻度污染     339
# 中度污染      88
# 重度污染      20
# 无          1
# Name: Level, dtype: int64

# %%
df['AQI'].plot(kind="hist",figsize=[5,5],legend=False,title="AQI 2014-2018")
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
plt.pie(conti_count, labels=conti, autopct='%1.1f%%')  # autopct 显示占比
plt.axis('equal')  # 调整坐标轴的比例
plt.show()

# %%
plt.plot(df.AQI, df.Level, 'g.')  # 'g.' 表示用绿色的点绘制
plt.show()

# %%
la = df['Level']
plt.pie(df.AQI, labels=la, autopct='%1.1f%%')  # autopct 显示占比
plt.axis('equal')  # 调整坐标轴的比例
plt.show()

# %%
pd.scatter_matrix(df)
plt.savefig('污染物.png')
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt 
plt.scatter(df.AQI, df.Level)
plt.xlabel('AQI')  # x轴名称
plt.ylabel('Level')   # y轴名称
plt.title('2014-2018）')  # 图标题
# Out:
# Text(0.5,1,'2014-2018）')
